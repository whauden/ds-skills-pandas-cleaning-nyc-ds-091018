# %% [markdown]
# # Import pandas and other packages to be used

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import and preview a dataset

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
df.shape
# Out:
# (197625, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
# C/A                                                                     197625 non-null object
# UNIT                                                                    197625 non-null object
# SCP                                                                     197625 non-null object
# STATION                                                                 197625 non-null object
# LINENAME                                                                197625 non-null object
# DIVISION                                                                197625 non-null object
# DATE                                                                    197625 non-null object
# TIME                                                                    197625 non-null object
# DESC                                                                    197625 non-null object
# ENTRIES                                                                 197625 non-null int64
# EXITS                                                                   197625 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# # Data Munging/ Manipulation
# This MTA turnstile dataset is a great place for us to get our hands dirty wrnagling and cleaning some data!
#
# Let's start by example by filtering the data down to all stations for the N line. To do this, we'll need to extract all "N"s from the LINENAME column, or similarly, create a column indicating whether or not the stop is an N line stop.

# %% [markdown]
# ### Defining Functions
#
# At this point, we will need to define some functions to perform data manipulation. In python, we define a function using the `def` keyword. Afterwords, we give the function a name, followed by parentheses. Any required (or optional parameters) are specified within the parentheses, just as you would normally call a function. You then specify the functions behavior using a colon and an indendation, much the same way you would a for loop or conditional block. Finally, if you want your function to return something (as with the str.pop() method) as opposed to a function that simply does something in the background but returns nothing (such as list.append()), you must use the `return` keyword. Note that as soon as a function hits a point in execution where something is returned, the function would terminate and no further commands would be executed. In other words the `return` command both returns a value and forces termination of the function.

# %%
def contains_n(text):
    if 'N' in text:
        return True
    else:
        return False

#or the shorter, more pythonic:
def contains_n(text):
    bool_val = 'N' in text
    return bool_val

# %%
df['On_N_Line'] = df.LINENAME.map(contains_n) #call a column with df.UNIT or df['UNIT']
df.head(2)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
#
#    On_N_Line
# 0       True
# 1       True

# %%
df.tail(2)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             TIME     DESC  ENTRIES  \
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         EXITS                                                                 \
# 197623                                                348
# 197624                                                348
#
#         On_N_Line
# 197623      False
# 197624      False

# %%
df.On_N_Line.value_counts(normalize=True)
# Out:
# False    0.870441
# True     0.129559
# Name: On_N_Line, dtype: float64

# %% [markdown]
# # Explanation
# Above we used the map method for pandas series. This allows us to pass a function that will be applied to each and every data entry within the series. As shorthand, we could also pass a lambda function to determine whether or not each row was on the N line or not.
# `df['On_N_Line'] = df.LINENAME.map(lambda x: 'N' in x)`
# This is shorter and equivalent to the above functions defined above. Lambda functions are often more covenient shorthand, but have less functionality then defining functions explicitly.

# %% [markdown]
# # Practice
# Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
def line_len(line):
    return len(line)

# %%
df['Num_Lines'] = df.LINENAME.map(line_len)

# %%
df['Num_Lines'] = df.LINENAME.map(lambda x: len(x)) #lambda = temporary function
df.sort_values('Num_Lines',ascending=False)
# Your code here
# Out:
#           C/A  UNIT       SCP         STATION      LINENAME DIVISION  \
# 132292   R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2676     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2677     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2678     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2679     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2680     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2681     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2682     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2683     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2684     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2685     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2687     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2702     A021  R032  01-00-02  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2688     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2689     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2690     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2691     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2692     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2693     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2694     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2695     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2696     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2697     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2698     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2699     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2700     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...       ...   ...       ...             ...           ...      ...
# 112535  PTH04  R551  00-04-04    GROVE STREET             1      PTH
# 112534  PTH04  R551  00-04-04    GROVE STREET             1      PTH
# 112558  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112559  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112560  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112561  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112584  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112583  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112582  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112581  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112580  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112579  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112578  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112577  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112576  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112575  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112574  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112573  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112572  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112571  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112570  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112569  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112568  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112567  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112566  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112565  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112564  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112563  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112562  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 197624  TRAM2  R469  00-05-01   RIT-ROOSEVELT             R      RIT
#
#               DATE      TIME     DESC  ENTRIES  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
# 2676    08/28/2018  04:00:00  REGULAR  2832359
# 2677    08/28/2018  08:00:00  REGULAR  2832561
# 2678    08/28/2018  09:57:08  REGULAR  2832815
# 2679    08/28/2018  12:00:00  REGULAR  2832994
# 2680    08/28/2018  16:00:00  REGULAR  2833390
# 2681    08/28/2018  20:00:00  REGULAR  2834686
# 2682    08/29/2018  00:00:00  REGULAR  2835069
# 2683    08/29/2018  04:00:00  REGULAR  2835109
# 2684    08/29/2018  08:00:00  REGULAR  2835310
# 2685    08/29/2018  12:00:00  REGULAR  2835721
# 2687    08/29/2018  20:00:00  REGULAR  2837390
# 2702    08/25/2018  04:00:00  REGULAR  1965089
# 2688    08/30/2018  00:00:00  REGULAR  2837721
# 2689    08/30/2018  04:00:00  REGULAR  2837752
# 2690    08/30/2018  08:00:00  REGULAR  2837924
# 2691    08/30/2018  08:49:06  REGULAR  2838018
# 2692    08/30/2018  12:00:00  REGULAR  2838332
# 2693    08/30/2018  16:00:00  REGULAR  2838767
# 2694    08/30/2018  20:00:00  REGULAR  2839999
# 2695    08/31/2018  00:00:00  REGULAR  2840336
# 2696    08/31/2018  04:00:00  REGULAR  2840375
# 2697    08/31/2018  08:00:00  REGULAR  2840537
# 2698    08/31/2018  12:00:00  REGULAR  2840895
# 2699    08/31/2018  16:00:00  REGULAR  2841591
# 2700    08/31/2018  20:00:00  REGULAR  2842280
# ...            ...       ...      ...      ...
# 112535  08/29/2018  03:54:11  REGULAR    53064
# 112534  08/28/2018  23:42:11  REGULAR    53064
# 112558  08/26/2018  04:04:23  REGULAR    28064
# 112559  08/26/2018  08:16:23  REGULAR    28074
# 112560  08/26/2018  12:28:23  REGULAR    28151
# 112561  08/26/2018  16:40:23  REGULAR    28229
# 112584  08/30/2018  17:16:23  REGULAR    32803
# 112583  08/30/2018  13:04:23  REGULAR    32726
# 112582  08/30/2018  08:52:23  REGULAR    32358
# 112581  08/30/2018  04:40:23  REGULAR    31911
# 112580  08/30/2018  00:28:23  REGULAR    31908
# 112579  08/29/2018  20:16:23  REGULAR    31883
# 112578  08/29/2018  16:04:23  REGULAR    31682
# 112577  08/29/2018  11:52:23  REGULAR    31616
# 112576  08/29/2018  07:40:23  REGULAR    31045
# 112575  08/29/2018  03:28:23  REGULAR    30850
# 112574  08/28/2018  23:16:23  REGULAR    30844
# 112573  08/28/2018  19:04:23  REGULAR    30744
# 112572  08/28/2018  14:52:23  REGULAR    30507
# 112571  08/28/2018  10:40:23  REGULAR    30358
# 112570  08/28/2018  06:28:23  REGULAR    29534
# 112569  08/28/2018  02:16:23  REGULAR    29500
# 112568  08/27/2018  22:04:23  REGULAR    29490
# 112567  08/27/2018  17:52:23  REGULAR    29332
# 112566  08/27/2018  13:40:23  REGULAR    29168
# 112565  08/27/2018  09:28:23  REGULAR    28975
# 112564  08/27/2018  05:16:23  REGULAR    28319
# 112563  08/27/2018  01:04:23  REGULAR    28318
# 112562  08/26/2018  20:52:23  REGULAR    28305
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         EXITS                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# 2676                                              3306438
# 2677                                              3306716
# 2678                                              3307705
# 2679                                              3308064
# 2680                                              3308536
# 2681                                              3309190
# 2682                                              3309328
# 2683                                              3309348
# 2684                                              3309579
# 2685                                              3310943
# 2687                                              3312091
# 2702                                              1942027
# 2688                                              3312246
# 2689                                              3312261
# 2690                                              3312478
# 2691                                              3312826
# 2692                                              3313701
# 2693                                              3314206
# 2694                                              3314879
# 2695                                              3315042
# 2696                                              3315061
# 2697                                              3315242
# 2698                                              3316295
# 2699                                              3316775
# 2700                                              3317347
# ...                                                   ...
# 112535                                              30905
# 112534                                              30893
# 112558                                              12480
# 112559                                              12483
# 112560                                              12494
# 112561                                              12514
# 112584                                              13807
# 112583                                              13762
# 112582                                              13726
# 112581                                              13640
# 112580                                              13639
# 112579                                              13597
# 112578                                              13414
# 112577                                              13390
# 112576                                              13260
# 112575                                              13245
# 112574                                              13237
# 112573                                              13164
# 112572                                              13036
# 112571                                              13013
# 112570                                              12894
# 112569                                              12893
# 112568                                              12881
# 112567                                              12754
# 112566                                              12698
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         On_N_Line  Num_Lines
# 132292       True         12
# 2686         True         12
# 2673         True         12
# 2674         True         12
# 2675         True         12
# 2676         True         12
# 2677         True         12
# 2678         True         12
# 2679         True         12
# 2680         True         12
# 2681         True         12
# 2682         True         12
# 2683         True         12
# 2684         True         12
# 2685         True         12
# 2687         True         12
# 2702         True         12
# 2688         True         12
# 2689         True         12
# 2690         True         12
# 2691         True         12
# 2692         True         12
# 2693         True         12
# 2694         True         12
# 2695         True         12
# 2696         True         12
# 2697         True         12
# 2698         True         12
# 2699         True         12
# 2700         True         12
# ...           ...        ...
# 112535      False          1
# 112534      False          1
# 112558      False          1
# 112559      False          1
# 112560      False          1
# 112561      False          1
# 112584      False          1
# 112583      False          1
# 112582      False          1
# 112581      False          1
# 112580      False          1
# 112579      False          1
# 112578      False          1
# 112577      False          1
# 112576      False          1
# 112575      False          1
# 112574      False          1
# 112573      False          1
# 112572      False          1
# 112571      False          1
# 112570      False          1
# 112569      False          1
# 112568      False          1
# 112567      False          1
# 112566      False          1
# 112565      False          1
# 112564      False          1
# 112563      False          1
# 112562      False          1
# 197624      False          1
#
# [197625 rows x 13 columns]

# %%
df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
# 5  REGULAR  6736562
# 6  REGULAR  6736683
# 7  REGULAR  6736696
# 8  REGULAR  6736705
# 9  REGULAR  6736746
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
# 5                                            2283425
# 6                                            2283460
# 7                                            2283461
# 8                                            2283483
# 9                                            2283524
#
#    On_N_Line  Num_Lines
# 0       True          7
# 1       True          7
# 2       True          7
# 3       True          7
# 4       True          7
# 5       True          7
# 6       True          7
# 7       True          7
# 8       True          7
# 9       True          7

# %% [markdown]
# # Cleaning Column Names
# Sometimes, you have messy column names. Observe:

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               ',
#        'On_N_Line', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# You might notice that foolishly, the EXITS column has a lot of annoying whitespace following it.
# We can quickly use a list comprehension to clean up all of the column names.

# %%
def col_edit(name):
    lower = df.columns.str.lower()
    return lower

# %%
df.columns = df.columns.map(lambda x: x.lower().replace('/',''))
df.columns
# Out:
# Index(['ca', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'on_n_line', 'num_lines'],
#       dtype='object')

# %%
df.head()
# Out:
#      ca  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    on_n_line  num_lines
# 0       True          7
# 1       True          7
# 2       True          7
# 3       True          7
# 4       True          7

# %% [markdown]
# ### Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.replace('/','').strip()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
df.columns = df.columns.map(clean)
df.columns
# Out:
# Index(['ca', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'on_n_line', 'num_lines'],
#       dtype='object')

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(x) for x in df.columns]

# %%
[lambda x: x.lower().strip().replace('/','') for col in df.columns]
# Out:
# [<function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>,
#  <function __main__.<listcomp>.<lambda>(x)>]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['ca', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'on_n_line', 'num_lines'],
#       dtype='object')

# %% [markdown]
# # Reformatting Column Types
# Another common data munging technique can be reformating column types. We first previewed column types above using the `df.info()` method, which we'll repeat here.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 13 columns):
# ca           197625 non-null object
# unit         197625 non-null object
# scp          197625 non-null object
# station      197625 non-null object
# linename     197625 non-null object
# division     197625 non-null object
# date         197625 non-null object
# time         197625 non-null object
# desc         197625 non-null object
# entries      197625 non-null float64
# exits        197625 non-null int64
# on_n_line    197625 non-null bool
# num_lines    197625 non-null int64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 18.3+ MB

# %% [markdown]
# A common transformation needed is converting numbers stored as text to *float* or *integer* representations. In this cas ENTRIES and EXITS are appropriately *int64*, but to practice, we'll demonstrate changing that to a float and then back to an int.

# %%
print(df.entries.dtype) #We can also check an individual column type rather then all 
df.entries = df.entries.astype(float) #Changing the column to float
print(df.entries.dtype) #Checking our changes
# Out:
# float64
# float64

# %%
#Converting Back
print(df.entries.dtype) 
df.entries = df.entries.astype(int)
print(df.entries.dtype)
# Out:
# float64
# int64

# %%
df.head()
# Out:
#      ca  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits  on_n_line  num_lines
# 0  REGULAR  6736067  2283184       True          7
# 1  REGULAR  6736087  2283188       True          7
# 2  REGULAR  6736105  2283229       True          7
# 3  REGULAR  6736180  2283314       True          7
# 4  REGULAR  6736349  2283384       True          7

# %% [markdown]
# Attempting to convert a string column to int or float will produce errors if there are actually non numeric characters

# %%
df.linename = df.linename.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-8e98b7be0096> in <module>()
# ----> 1 df.linename = df.linename.astype(int)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: 'NQR456W'

# %% [markdown]
# # Converting Dates
# A slightly more complicated data type transformation is creating *date* or *datetime* objects. These are built in datatypes that have useful information such as being able to quickly calculate the time between two days, or extracting the day of the week from a given date. However, if we look at our current date column, we will notice it is simply a *non-null object* (probably simply text).

# %%
df.date.dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df.date).head()
# Out:
# 0   2018-08-25
# 1   2018-08-25
# 2   2018-08-25
# 3   2018-08-25
# 4   2018-08-25
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# # pd.to_datetime()
# This is the handiest of methods when converting strings to datetime objects.

# %%
#Often you can simply pass the series into this method.
pd.to_datetime(df.date).head() #It is good practice to preview the results first
#This prevents overwriting data if some error was produced. However everything looks good!
# Out:
# 0   2018-08-25
# 1   2018-08-25
# 2   2018-08-25
# 3   2018-08-25
# 4   2018-08-25
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Sometimes the above won't work and you'll have to explicitly pass how the date is formatted.
# To do that, you have to use some datetime codes. Here's a preview of some of the most common ones:
# <img src="strftime_codes.png" width=600>

# %% [markdown]
# To explicitly pass formatting parameters, preview your dates and write the appropriate codes.

# %%
df.date.iloc[0] #Another method for slicing series/dataframes
# Out:
# '08/25/2018'

# %%
#Notice we include delimiters (in this case /) between the codes.
pd.to_datetime(df.date, format='%m/%d/%Y').head()
# Out:
# 0   2018-08-25
# 1   2018-08-25
# 2   2018-08-25
# 3   2018-08-25
# 4   2018-08-25
# Name: date, dtype: datetime64[ns]

# %%
#Actually apply and save our changes
df.date = pd.to_datetime(df.date)
print(df.date.dtype)
#Preview updated dataframe
df.head(2)
# Out:
# datetime64[ns]
#      ca  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
#
#       desc  entries    exits  on_n_line  num_lines
# 0  REGULAR  6736067  2283184       True          7
# 1  REGULAR  6736087  2283188       True          7

# %% [markdown]
# # Datetime Methods
# Now that we have converted the DATE field to a datetime object we can use some useful built in methods.

# %%
#dt stores all the built in datetime methods (only works for datetime columns)
df.date.dt.day_name().head()
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: date, dtype: object

# %% [markdown]
# # Groupby Methods
# Let's look at one more extremely important method. Groupby allows you to aggregate the data based on a field. You then apply an aggregation function such as *mean*, *median*, *count*, *min*, *max*, or even a custom function which you can define yourself!

# %%
df.groupby('station').sum().head()
# Out:
#                     entries         exits  on_n_line  num_lines
# station
# 1 AV           127637422994   68336694378        0.0        420
# 103 ST           6809043268   26408857862        0.0        790
# 103 ST-CORONA    2936772648    3007136644        0.0        396
# 104 ST         201698739525  146808927663        0.0        541
# 110 ST           1485948761    1430806219        0.0        252

# %%
#df.groupby('station').entries.mean().head()
df.head()
# Out:
#      ca  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  on_n_line  num_lines
# 0  REGULAR  6736067  2283184       True          7
# 1  REGULAR  6736087  2283188       True          7
# 2  REGULAR  6736105  2283229       True          7
# 3  REGULAR  6736180  2283314       True          7
# 4  REGULAR  6736349  2283384       True          7

# %% [markdown]
# Notice that our groupby column becomes the index of the resulting view. To change this, you can also use the `.reset_index()` method.

# %%
df.groupby('station').sum().reset_index().head()
# Out:
#          station       entries         exits  on_n_line  num_lines
# 0           1 AV  127637422994   68336694378        0.0        420
# 1         103 ST    6809043268   26408857862        0.0        790
# 2  103 ST-CORONA    2936772648    3007136644        0.0        396
# 3         104 ST  201698739525  146808927663        0.0        541
# 4         110 ST    1485948761    1430806219        0.0        252

# %% [markdown]
# Finally, we could graph these as before.

# %%
df.columns = [col.strip() for col in df.columns]

# %%
df.groupby('station').sum().sort_values('entries')[['entries', 'exits']]
#df.groupby('station')[['entries', 'exits']].sum().sort_values('entries') - sum only the entries and exits columns
# Out:
#                       entries         exits
# station
# NEWARK HM HE         17895377     269451807
# ORCHARD BEACH        20394086       1243493
# PATH WTC 2           40491009     116622363
# JFK JAMAICA CT1      42927031      45442756
# HARRISON             51214676     114838895
# BROAD CHANNEL        66828478       9584000
# 9TH STREET           75165836      91067064
# NEWARK C             78345233      14686772
# BEACH 44 ST          92872482      80912118
# COURT SQ-23 ST       95073563      27837811
# NEWARK HW BMEBE      96050463     204721126
# SUTTER AV           104359549      67059885
# NEWARK BM BW        113685552      11520480
# ATLANTIC AV         130464626      53528694
# LACKAWANNA          145069382     194332192
# 14TH STREET         153559568      56584759
# NEW UTRECHT AV      158152141     123716883
# 21 ST               158488090     157171195
# TWENTY THIRD ST     187026470     123029982
# BEACH 36 ST         198286610     198163523
# BEACH 98 ST         203128425     218798188
# E 143/ST MARY'S     227782075     256937684
# THIRTY ST           237352315     205709549
# AQUEDUCT N.COND     237358646     187304670
# PENNSYLVANIA AV     237556338      81264290
# MORISN AV/SNDVW     238873181     245701308
# GROVE STREET        240301385     279377109
# BOTANIC GARDEN      244362649     128769322
# BEACH 90 ST         257876131     263227538
# CENTRAL AV          259033142     283867655
# ...                       ...           ...
# 170 ST            88479484438   86061519249
# EASTCHSTER/DYRE   88630175643   95781532066
# 161/YANKEE STAD   89366421550   58606633116
# 5 AVE            102739222448   41385864222
# BOWLING GREEN    104147509910   76427004320
# 47-50 STS ROCK   106633645842  107263912635
# CORTLANDT ST     109750002860   39023880554
# LEXINGTON AV/53  114824245010  151219373952
# HIGH ST          115905651379  155899805639
# COURT SQ         118821577805   53570226963
# 1 AV             127637422994   68336694378
# FLATBUSH AV-B.C  129901381361   95290151693
# 59 ST COLUMBUS   144678049477  126491191032
# DEKALB AV        148686972133   88082581090
# 23 ST            156861222415  180610559425
# 125 ST           157574010389   84930450880
# 72 ST            163766987098  214138415522
# 34 ST-PENN STA   168826720223  125221171641
# 57 ST-7 AV       175784106220  129414304584
# 59 ST            176583512281  101044162146
# FULTON ST        182543044842  183842894603
# 183 ST           190835569160  113184503080
# 14 ST            192598780162  136157933615
# 104 ST           201698739525  146808927663
# CHAMBERS ST      213612472635  187240807848
# 34 ST-HERALD SQ  236423307073  306437102568
# TIMES SQ-42 ST   249007457671  191136013457
# CANAL ST         252795822167  253210309341
# 3 AV-149 ST      299716036833  198477900422
# 42 ST-PORT AUTH  319107445538  260460012505
#
# [373 rows x 2 columns]

# %%
to_graph = df.groupby('station').sum().sort_values('entries')[['entries', 'exits']]
#Recall that default behavior for .sort_values() is ascending.
#Hence, we look at the tail rather then head for top values
#Alternatively, we could use .sort_values(ascending=False) followed by the .head() method
to_graph.tail(10).plot(kind='barh'); #semicolon removes extra printed data
plt.title('Top 10 Stations Based on Number of Entries.');
plt.xlabel('Number of Entries/Exits');

# %% [markdown]
# # Practice
# Here we begin to do some exploratory analysis to answer some questions.

# %% [markdown]
# # 1. Compare subway traffic by day of the week. Display this as a graph.

# %%
df['day_of_week'] = df.date.dt.day_name()
#df.day_of_week = pd.to_datetime(df.date,format='%a')
to_graph = df.groupby('day_of_week').sum().sort_values('entries')[['entries','exits']]
to_graph.plot(kind='barh')
#df.groupby('date').dt.dayofweek.head()#Your code here

# %% [markdown]
# # 2. Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
traffic = df.groupby('day_of_week').sum().sort_values('entries',ascending=False)#Your code here

# %%
traffic.reset_index()
# Out:
#   day_of_week        entries         exits  on_n_line  num_lines
# 0      Sunday  1192306179082  959223750461     3606.0      75306
# 1     Tuesday  1143313287046  942230721477     3667.0      77303
# 2   Wednesday  1123655222441  920630864687     3639.0      75713
# 3    Thursday  1122723988662  920691927110     3702.0      76607
# 4    Saturday  1115661545514  909142081474     3609.0      74725
# 5      Monday  1114237052454  911938153513     3740.0      76110
# 6      Friday  1110224700078  906799065337     3641.0      75573
